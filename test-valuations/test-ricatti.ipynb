# %%
AttachSpec("../diffalg.spec");
Z:=Integers();
Q:=RationalField();

R<t>:=PolynomialRing(Q,1);
f := map<R->R|f:->Derivative(f,t)>;
A := DifferentialRing(R, f, Q);
F<t> := FieldOfFractions(A);
P<x,y>:=PolynomialRingProlSeq(F,2: term_order:=<"dblocks",[[1,2]]>);

# %%
f:= Diff(x,1) - 1 -x -x^2;

# %%
Diff(x,1);
# Out:
# Diff(x,1)

# %%
m:=5;
seq:=[Diff(f,r) : r in [0..5]];
vars:=Jet([Diff(x,r) : r in [0..5]],6);

# %%
vars[1] in Jet(P,6);
# Out:
# true

# %%
I:=ideal<Jet(P,6)|Jet(seq)>;

# %%
GroebnerBasis(I);
# Out:
# [
# Diff(x,6) + -720*x^7 + -2520*x^6 + -5040*x^5 + -6300*x^4 + -5418*x^3 + -3087*x^2 + -1107*x + -189,
# Diff(x,5) + -120*x^6 + -360*x^5 + -630*x^4 + -660*x^3 + -459*x^2 + -189*x + -39,
# Diff(x,4) + -24*x^5 + -60*x^4 + -90*x^3 + -75*x^2 + -39*x + -9,
# Diff(x,3) + -6*x^4 + -12*x^3 + -15*x^2 + -9*x + -3,
# Diff(x,2) + -2*x^3 + -3*x^2 + -3*x + -1,
# Diff(x,1) + -1*x^2 + -1*x + -1
# ]

# %%
Diff(x,2) + -2*x^3 + -3*x^2 + -3*x + -1 eq seq[3];
# Out:
# false

# %%
f;
Diff(f);
# Out:
# Diff(x,1) + -1*x^2 + -1*x + -1
# Diff(x,2) + -2*x*Diff(x,1) + -1*Diff(x,1)
